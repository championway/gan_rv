# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import os

# %%
img = cv2.imread("/media/arg_ws3/5E703E3A703E18EB/data/mm_FCN/unity/image/kellogg_108_Scene89_5_original.png")

# %%
mask = cv2.imread("/media/arg_ws3/5E703E3A703E18EB/data/mm_FCN/unity/mask/kellogg_108_Scene89_5_seg.png",cv2.IMREAD_UNCHANGED)

# %%
plt.imshow(img)

# %%
mask[300][200]
# Out:
# 8

# %%
img[img > 0] = 5

# %%
print(img[100][300])
# Out:
# 5

# %%
plt.figure(figsize = (10, 12))
for i in range(2):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.subplot(2, 2, i*2 + 1)
    plt.title("origin_img")
    plt.imshow(img)

    plt.subplot(2, 2, i*2 + 2)
    plt.title("label_img")
    plt.imshow(mask,cmap = "brg",vmin = 0, vmax = 1)

plt.show()
