# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import os

# %%
img = cv2.imread("/media/arg_ws3/5E703E3A703E18EB/data/mm_FCN/real/image/3m_scene_000000_000005.jpg")

# %%
mask = cv2.imread("/media/arg_ws3/5E703E3A703E18EB/data/mm_FCN/real/mask/3m_scene_000012_000018.png",cv2.IMREAD_UNCHANGED)

# %%
plt.imshow(img)

# %%
print(mask[0][400])
print(mask[400][100])
#a = mask[:,:,2]
print(len(mask.shape))
#print(a[0][400])
#print(a[400][100])
# Out:
# 0
# 0
# 2

# %%
mask[mask > 0] = 5

# %%
print(mask[0][400])
print(mask[400][200])
# Out:
# [0 5 0]
# [0 0 5]

# %%
a = mask[:,:,2]

# %%
print(a[0][400])
print(a[400][200])
# Out:
# 0
# 5

# %%
print(img[100][300])
# Out:
# 5

# %%
plt.figure(figsize = (10, 12))
for i in range(2):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.subplot(2, 2, i*2 + 1)
    plt.title("origin_img")
    plt.imshow(img)

    plt.subplot(2, 2, i*2 + 2)
    plt.title("label_img")
    plt.imshow(mask,cmap = "brg",vmin = 0, vmax = 1)

plt.show()
